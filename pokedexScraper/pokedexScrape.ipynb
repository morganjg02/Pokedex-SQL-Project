# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://pokemondb.net/pokedex/all'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
headers = soup.find_all('th')
header_text = [th.text.strip() for th in headers]

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = header_text)
df
# Out:
# Empty DataFrame
# Columns: [#, Name, Type, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed]
# Index: []

# %%
column_data = soup.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#          #                     Name           Type Total   HP Attack Defense  \
# 0     0001                Bulbasaur   Grass Poison   318   45     49      49
# 1     0002                  Ivysaur   Grass Poison   405   60     62      63
# 2     0003                 Venusaur   Grass Poison   525   80     82      83
# 3     0003   Venusaur Mega Venusaur   Grass Poison   625   80    100     123
# 4     0004               Charmander           Fire   309   39     52      43
# ...    ...                      ...            ...   ...  ...    ...     ...
# 1214  1023               Iron Crown  Steel Psychic   590   90     72     100
# 1215  1024    Terapagos Normal Form         Normal   450   90     65      85
# 1216  1024  Terapagos Terastal Form         Normal   600   95     95     110
# 1217  1024   Terapagos Stellar Form         Normal   700  160    105     110
# 1218  1025                Pecharunt   Poison Ghost   600   88     88     160
#
#      Sp. Atk Sp. Def Speed
# 0         65      65    45
# 1         80      80    60
# 2        100     100    80
# 3        122     120    80
# 4         60      50    65
# ...      ...     ...   ...
# 1214     122     108    98
# 1215      65      85    60
# 1216     105     110    85
# 1217     130     110    85
# 1218      88      88    88
#
# [1219 rows x 10 columns]

# %%
df.to_csv(r'C:\Users\subze\pokedexProject\pokedexScraper\pokedexData.csv', index = False)
